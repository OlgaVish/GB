# %% [markdown]
# Тема "Вычисления с помощью Numpy"

# %% [markdown]
# Задание 1

# %% [markdown]
# Импортируйте библиотеку Numpy и дайте ей псевдоним np.

# %%
import numpy as np

# %% [markdown]
# Создайте массив Numpy под названием "a" размером 5x2, то есть состоящий из 5 строк и 2 столбцов. Первый столбец должен содержать числа 1, 2, 3, 3, 1, а второй - числа 6, 8, 11, 10, 7.

# %%
a = np.array([[1,6], 
              [2,8], 
              [3,11], 
              [3,10], 
              [1,7]], dtype=int)
print(a)
print('Форма a: {}'.format(a.shape))
# Out:
# [[ 1  6]
#  [ 2  8]
#  [ 3 11]
#  [ 3 10]
#  [ 1  7]]
# Форма a: (5, 2)

# %% [markdown]
# Будем считать, что каждый столбец - это признак, а строка - наблюдение. Затем найдите среднее значение по каждому признаку, используя метод mean массива Numpy.

# %%
print('Среднее значение по каждому признаку: {}'.format(a.mean(axis=0)))
# Out:
# Среднее значение по каждому признаку: [2.  8.4]

# %% [markdown]
# Результат записать в массив "mean_a", в нем должно быть 2 элемента.

# %%
mean_a = a.mean(axis=0).copy()

# %%
print(mean_a)
# Out:
# [2.  8.4]

# %% [markdown]
# Задание 2

# %% [markdown]
# Вычислите массив "a_centered", отняв от значений массива "а" средние значения соответствующих признаков, содержащиеся в массиве "mean_a". Вычисление должно производиться в одно действие. Получившийся массив должен иметь размер 5x2.

# %%
print('Массив a: ')
print(a)

print('Массив mean_a: ')
print(mean_a)
# Out:
# Массив a:
# [[ 1  6]
#  [ 2  8]
#  [ 3 11]
#  [ 3 10]
#  [ 1  7]]
# Массив mean_a:
# [2.  8.4]

# %%
a_centered = a - mean_a
print('Массив a_centered: ')
print(a_centered)
# Out:
# Массив a_centered:
# [[-1.  -2.4]
#  [ 0.  -0.4]
#  [ 1.   2.6]
#  [ 1.   1.6]
#  [-1.  -1.4]]

# %% [markdown]
# Задание 3

# %% [markdown]
# Найдите скалярное произведение столбцов массива "a_centered". В результате должна получиться величина "a_centered_sp".

# %%
j1 = a_centered[:, :1].copy()
print(j1)
j1_t = j1.T
# Out:
# [[-1.]
#  [ 0.]
#  [ 1.]
#  [ 1.]
#  [-1.]]

# %%
j2 = a_centered[:, 1:].copy()
print(j2)
# Out:
# [[-2.4]
#  [-0.4]
#  [ 2.6]
#  [ 1.6]
#  [-1.4]]

# %%
a_centered_sp = j1_t.dot(j2)[0, 0]
print(a_centered_sp)
# Out:
# 8.0

# %% [markdown]
# Затем поделите "a_centered_sp" на N-1, где N - число наблюдений.

# %%
N = 5
cov_res = a_centered_sp/(N-1)
print(cov_res)
# Out:
# 2.0

# %% [markdown]
# Задание 4**

# %% [markdown]
# В этом задании проверьте получившееся число, вычислив ковариацию еще одним способом - с помощью функции np.cov. В качестве аргумента m функция np.cov должна принимать транспонированный массив "a". В получившейся ковариационной матрице искомое значение ковариации будет равно элементу в строке с индексом 0 и столбце с индексом 1.

# %%
a_t = a.T
print(a_t)
# Out:
# [[ 1  2  3  3  1]
#  [ 6  8 11 10  7]]

# %%
cov_matrix = np.cov(a_t)
print(cov_matrix)
# Out:
# [[1.  2. ]
#  [2.  4.3]]

# %%
cov_res = cov_matrix[0, 1]
print(cov_res)
# Out:
# 2.0

# %% [markdown]
# Тема "Работа с данными в Pandas"

# %% [markdown]
# Задание 1

# %% [markdown]
# Импортируйте библиотеку Pandas и дайте ей псевдоним pd. Создайте датафрейм "authors" со столбцами "author_id" и "author_name", в которых соответственно содержатся данные: [1, 2, 3] и ['Тургенев', 'Чехов', 'Островский'].

# %%
import pandas as pd

# %%
a = {
    "author_id": [1, 2, 3],
    "author_name": ['Тургенев', 'Чехов', 'Островский']
}
authors = pd.DataFrame(a)
print(authors)
# Out:
#    author_id author_name
# 0          1    Тургенев
# 1          2       Чехов
# 2          3  Островский

# %% [markdown]
# Затем создайте датафрейм "book" cо столбцами "author_id", "book_title" и "price", в которых соответственно содержатся данные:
# [1, 1, 1, 2, 2, 3, 3],
# ['Отцы и дети', 'Рудин', 'Дворянское гнездо', 'Толстый и тонкий', 'Дама с собачкой', 'Гроза', 'Таланты и поклонники'],
# [450, 300, 350, 500, 450, 370, 290].

# %%
b = {
    "author_id": [1, 1, 1, 2, 2, 3, 3],
    "book_title": ['Отцы и дети', 'Рудин', 'Дворянское гнездо', 'Толстый и тонкий', 'Дама с собачкой', 'Гроза', 'Таланты и поклонники'], 
    "price": [450, 300, 350, 500, 450, 370, 290]
}
book = pd.DataFrame(b)
print(book)
# Out:
#    author_id            book_title  price
# 0          1           Отцы и дети    450
# 1          1                 Рудин    300
# 2          1     Дворянское гнездо    350
# 3          2      Толстый и тонкий    500
# 4          2       Дама с собачкой    450
# 5          3                 Гроза    370
# 6          3  Таланты и поклонники    290

# %% [markdown]
# Задание 2

# %% [markdown]
# Получите датафрейм "authors_price", соединив датафреймы "authors" и "books" по полю "author_id".

# %%
authors_price = pd.merge(authors, book, on='author_id', how='inner')
print(authors_price)
# Out:
#    author_id author_name            book_title  price
# 0          1    Тургенев           Отцы и дети    450
# 1          1    Тургенев                 Рудин    300
# 2          1    Тургенев     Дворянское гнездо    350
# 3          2       Чехов      Толстый и тонкий    500
# 4          2       Чехов       Дама с собачкой    450
# 5          3  Островский                 Гроза    370
# 6          3  Островский  Таланты и поклонники    290

# %% [markdown]
# Задание 3

# %% [markdown]
# Создайте датафрейм "top5", в котором содержатся строки из "authors_price" с пятью самыми дорогими книгами.

# %%
top5 = authors_price.nlargest(5, "price")
print(top5)
# Out:
#    author_id author_name         book_title  price
# 3          2       Чехов   Толстый и тонкий    500
# 0          1    Тургенев        Отцы и дети    450
# 4          2       Чехов    Дама с собачкой    450
# 5          3  Островский              Гроза    370
# 2          1    Тургенев  Дворянское гнездо    350

# %% [markdown]
# Задание 4

# %% [markdown]
# Создайте датафрейм "authors_stat" на основе информации из "authors_price". В датафрейме "authors_stat" должны быть четыре столбца:
# "author_name", "min_price", "max_price" и "mean_price", в которых должны содержаться соответственно имя автора, минимальная, максимальная и средняя цена на книги этого автора.

# %%
authors_price.sort_values(by="author_name", inplace=True)
authors_price
# Out:
#    author_id author_name            book_title  price
# 5          3  Островский                 Гроза    370
# 6          3  Островский  Таланты и поклонники    290
# 0          1    Тургенев           Отцы и дети    450
# 1          1    Тургенев                 Рудин    300
# 2          1    Тургенев     Дворянское гнездо    350
# 3          2       Чехов      Толстый и тонкий    500
# 4          2       Чехов       Дама с собачкой    450

# %%
groupby = authors_price.groupby("author_name")

# %%
col2 = groupby["price"].min()
col2
# Out:
# author_name
# Островский    290
# Тургенев      300
# Чехов         450
# Name: price, dtype: int64

# %%
col3 = groupby["price"].max()
col3
# Out:
# author_name
# Островский    370
# Тургенев      450
# Чехов         500
# Name: price, dtype: int64

# %%
col4 = groupby["price"].mean()
col4
# Out:
# author_name
# Островский    330.000000
# Тургенев      366.666667
# Чехов         475.000000
# Name: price, dtype: float64

# %%
c = {
    "author_name": authors_price["author_name"].unique(),
    "min_price": col2.values,
    "max_price": col3.values,
    "mean_price": col4.values
}
authors_stat = pd.DataFrame(c)
print(authors_stat)
# Out:
#   author_name  min_price  max_price  mean_price
# 0  Островский        290        370  330.000000
# 1    Тургенев        300        450  366.666667
# 2       Чехов        450        500  475.000000

# %% [markdown]
# Задание 5**

# %% [markdown]
# Создайте новый столбец в датафрейме "authors_price" под названием "cover", в нем будут располагаться данные о том, какая обложка у данной книги - твердая или мягкая. В этот столбец поместите данные из следующего списка:
# ['твердая', 'мягкая', 'мягкая', 'твердая', 'твердая', 'мягкая', 'мягкая'].

# %%
authors_price.sort_values(by="author_id", inplace=True)
print(authors_price)
# Out:
#    author_id author_name            book_title  price
# 0          1    Тургенев           Отцы и дети    450
# 1          1    Тургенев                 Рудин    300
# 2          1    Тургенев     Дворянское гнездо    350
# 3          2       Чехов      Толстый и тонкий    500
# 4          2       Чехов       Дама с собачкой    450
# 5          3  Островский                 Гроза    370
# 6          3  Островский  Таланты и поклонники    290

# %%
authors_price["cover"] = ['твердая', 'мягкая', 'мягкая', 'твердая', 'твердая', 'мягкая', 'мягкая']
print(authors_price)
# Out:
#    author_id author_name            book_title  price    cover
# 0          1    Тургенев           Отцы и дети    450  твердая
# 1          1    Тургенев                 Рудин    300   мягкая
# 2          1    Тургенев     Дворянское гнездо    350   мягкая
# 3          2       Чехов      Толстый и тонкий    500  твердая
# 4          2       Чехов       Дама с собачкой    450  твердая
# 5          3  Островский                 Гроза    370   мягкая
# 6          3  Островский  Таланты и поклонники    290   мягкая

# %% [markdown]
# Для каждого автора посчитайте суммарную стоимость книг в твердой и мягкой обложке. Используйте для этого функцию pd.pivot_table. При этом столбцы должны называться "твердая" и "мягкая", а индексами должны быть фамилии авторов. Пропущенные значения стоимостей заполните нулями, при необходимости загрузите библиотеку Numpy.

# %%
book_info = authors_price.pivot_table(index="author_name", columns="cover", values="price", aggfunc=np.sum, fill_value=0)
book_info
# Out:
# cover        мягкая  твердая
# author_name
# Островский      660        0
# Тургенев        650      450
# Чехов             0      950

# %% [markdown]
# Назовите полученный датасет "book_info" и сохраните его в формат pickle под названием "book_info.pkl". Затем загрузите из этого файла датафрейм и назовите его "book_info2". Удостоверьтесь, что датафреймы "book_info" и "book_info2" идентичны.

# %%
book_info.to_pickle("book_info.pkl")

# %%
book_info2 = pd.read_pickle("book_info.pkl")

# %%
book_info == book_info2
# Out:
# cover        мягкая  твердая
# author_name
# Островский     True     True
# Тургенев       True     True
# Чехов          True     True

# %% [markdown]
# Конец
